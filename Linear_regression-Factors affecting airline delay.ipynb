# %%
import warnings
warnings.simplefilter("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset =pd.read_csv("airlines.csv")
dataset.head()
# Out:
#   Airport.Code                                       Airport.Name  Time.Month  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...           6
# 1          BOS                    Boston, MA: Logan International           6
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...           6
# 3          CLT     Charlotte, NC: Charlotte Douglas International           6
# 4          DCA  Washington, DC: Ronald Reagan Washington National           6
#
#   Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0            June       2003                            1009
# 1            June       2003                             374
# 2            June       2003                             296
# 3            June       2003                             300
# 4            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  Statistics.# of Delays.Security  \
# ...

# %%
dataset.shape
# Out:
# (4408, 11)

# %%
dataset
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#       Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# ...

# %%
dataset.plot(x='Statistics.# of Delays.Late Aircraft', y='Statistics.# of Delays.Security',style='o' )    
plt.title('Statistics.# of Delays.Late Aircraft vs Statistics.# of Delays.Security')    
plt.xlabel('Statistics.# of Delays.Late Aircraft')    
plt.ylabel('Statistics.# of Delays.Security')    
plt.show()

# %%
dataset.plot(x='Statistics.# of Delays.Late Aircraft', y='Statistics.# of Delays.Weather',style='o' )    
plt.title('Statistics.# of Delays.Late Aircraft % vs Statistics.# of Delays.Weather')    
plt.xlabel('Statistics.# of Delays.Late Aircraft')    
plt.ylabel('Statistics.# of Delays.Weather')    
plt.show()

# %%
new_set = dataset.drop(['Airport.Code','Airport.Name','Time.Month','Time.Month Name','Time.Year','Statistics.# of Delays.Carrier','Statistics.Carriers.Total','Statistics.Flights.Cancelled'], axis=1)

# %%
new_set
# Out:
#       Statistics.# of Delays.Late Aircraft  Statistics.# of Delays.Security  \
# 0                                     1275                               17
# 1                                      495                                3
# 2                                      477                                8
# 3                                      472                                2
# 4                                      268                                4
# ...                                    ...                              ...
# 4403                                   397                                2
# 4404                                   513                                2
# 4405                                   947                                2
# 4406                                   540                                3
# 4407                                   342                                2
#
#       Statistics.# of Delays.Weather
# ...

# %%
new_set.head()
# Out:
#    Statistics.# of Delays.Late Aircraft  Statistics.# of Delays.Security  \
# 0                                  1275                               17
# 1                                   495                                3
# 2                                   477                                8
# 3                                   472                                2
# 4                                   268                                4
#
#    Statistics.# of Delays.Weather
# 0                             328
# 1                              66
# 2                              78
# 3                              54
# 4                              58

# %%
x=new_set.iloc[:,0]

# %%
x.shape
# Out:
# (4408,)

# %%
x=new_set.iloc[:,0].values.reshape(-1,1)

# %%
x.shape
# Out:
# (4408, 1)

# %%
x
# Out:
# array([[1275],
#        [ 495],
#        [ 477],
#        ...,
#        [ 947],
#        [ 540],
#        [ 342]], dtype=int64)

# %%
y = new_set.iloc[:,1]

# %%
y.shape
# Out:
# (4408,)

# %%
y=new_set.iloc[:,1].values.reshape(-1,1)

# %%
y
# Out:
# array([[17],
#        [ 3],
#        [ 8],
#        ...,
#        [ 2],
#        [ 3],
#        [ 2]], dtype=int64)

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (3526, 1)

# %%
x_test.shape
# Out:
# (882, 1)

# %%
y_train.shape
# Out:
# (3526, 1)

# %%
y_test.shape
# Out:
# (882, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([[ 5.36957882],
#        [ 6.46417218],
#        [ 4.23120172],
#        [ 4.40296868],
#        [ 3.75294863],
#        [14.5372192 ],
#        [ 7.0704085 ],
#        [ 8.62641506],
#        [ 3.86409195],
#        [ 5.43693841],
#        [ 3.89440377],
#        [13.00815648],
#        [ 4.80712623],
#        [ 4.04596285],
#        [ 5.97918312],
#        [ 4.66903907],
#        [ 4.33897707],
#        [ 4.24467364],
#        [ 3.63843732],
#        [ 6.22841361],
#        [11.98429069],
#        [ 4.52084797],
#        [ 3.73610873],
#        [ 4.77007845],
#        [ 3.60475752],
#        [ 5.95223928],
#        [ 7.57560543],
#        [ 4.36255293],
#        [ 9.89951134],
#        [ 5.57502557],
#        [ 4.75660654],
#        [ 4.06280275],
#        [ 3.69906095],
#        [ 5.60533739],
#        [ 3.81694024],
#        [ 3.64854126],
#        [11.63738879],
#        [ 4.70945482],
#        [ 5.02267692],
#        [ 7.30953505],
#        [ 5.18770792],
# ...

# %%
plt.scatter(x,y, color = 'yellow')
plt.plot(x_test,y_pred, color = 'blue')
